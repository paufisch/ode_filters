# %%
import functools

import jax
import jax.numpy as np
import jax.random as jrandom
import matplotlib.pyplot as plt

from ode_filters import (
    gaussian_filter,
    prepare_observations,
    rts_smoother,
    taylor_mode_initialization,
)
from ode_filters.measurement import (
    Measurement,
    SecondOrderODEInformation,
)
from ode_filters.priors import IWP

# Static (uncalibrated) filter, matching the old ekf1_sqr_loop.
jit_filter = jax.jit(
    functools.partial(gaussian_filter, calibration="none"), static_argnums=(2, 3, 4, 5)
)
jit_smoother = jax.jit(rts_smoother, static_argnums=(0,))

# Damped harmonic oscillator parameters
omega, zeta = 1.0, 0.1
gamma = 2 * zeta * omega
omega_d = np.sqrt(1 - zeta**2) * omega  # damped frequency
tspan, N = (0, 30), 100
ts = np.linspace(tspan[0], tspan[1], N + 1)

# --- consistent plot style (docs) ---
plt.rcParams.update(
    {
        "figure.dpi": 120,
        "savefig.dpi": 120,
        "savefig.bbox": "tight",
        "axes.spines.top": False,
        "axes.spines.right": False,
        "axes.grid": True,
        "grid.alpha": 0.3,
        "grid.linewidth": 0.6,
        "axes.axisbelow": True,
        "lines.linewidth": 2.0,
        "legend.frameon": False,
        "font.size": 11,
        "axes.titlesize": 12,
        "axes.labelsize": 11,
    }
)

# %%
# Basic second-order ODE: d^2x/dt^2 = -omega^2 * x - gamma * dx/dt
def vf(x, dx, *, t):
    return -(omega**2) * x - gamma * dx


x0, dx0 = np.array([1.0]), np.array([0.0])
prior = IWP(q=2, d=1, Xi=1 * np.eye(1))
mu_0, Sigma_0_sqr = taylor_mode_initialization(vf, (x0, dx0), q=2, order=2)
measure = SecondOrderODEInformation(vf, prior.E0, prior.E1, prior.E2)

# %%
# Run filter and smoother
result = jit_filter(mu_0, Sigma_0_sqr, prior, measure, tspan, N)
m_smooth, P_smooth_sqr = jit_smoother(prior, result)
m_smooth, P_smooth_sqr = np.array(m_smooth), np.array(P_smooth_sqr)

# %%
# Plot smoothed estimate vs true solution
x_true = np.exp(-zeta * omega * ts) * (
    np.cos(omega_d * ts) + (zeta * omega / omega_d) * np.sin(omega_d * ts)
)

P_smooth = np.einsum("ijk,ijl->ikl", P_smooth_sqr, P_smooth_sqr)
margin = 2 * np.sqrt(P_smooth[:, 0, 0])

plt.figure(figsize=(10, 3))
plt.plot(ts, m_smooth[:, 0], label="smoothed")
plt.plot(ts, x_true, "k--", label="true")
plt.fill_between(ts, m_smooth[:, 0] - margin, m_smooth[:, 0] + margin, alpha=0.3)
plt.xlabel("t"), plt.ylabel("x(t)"), plt.legend()
plt.show()

# %%
# Acceleration measurements using full_state=True
# For a second-order ODE with q=2, the state vector is X = [x, dx, ddx].
# A standard Measurement observes A @ x (= A @ E0 @ X), but acceleration
# lives in the full state vector. Using full_state=True, we can define
# A @ X directly, e.g. A = E2 to observe ddx.

# True velocity and acceleration from the exact solution
dx_true = -omega_d * np.sin(omega_d * ts) * np.exp(
    -zeta * omega * ts
) - zeta * omega * np.cos(omega_d * ts) * np.exp(-zeta * omega * ts)
ddx_true = -(omega**2) * x_true - gamma * dx_true

# Subsample acceleration observations (every 5th step)
accel_noise_std = 0.05
key = jrandom.PRNGKey(123)
obs_every = 5
accel_indices = np.arange(obs_every, N + 1, obs_every)
accel_ts = ts[accel_indices]
accel_true = ddx_true[accel_indices]
accel_z = (
    accel_true + accel_noise_std * jrandom.normal(key, shape=accel_true.shape)
).reshape(-1, 1)

plt.figure(figsize=(10, 3))
plt.scatter(accel_ts, accel_z, s=20, color="red", label="noisy acceleration obs")
plt.plot(ts, ddx_true, "k--", label="true acceleration")
plt.xlabel("t"), plt.ylabel("ddx(t)"), plt.legend()
plt.title("Acceleration measurements")
plt.show()

# %%
# Assimilate acceleration measurements via an external observation model.
#
# In the consolidated API, external observations are passed through an
# ``ObsModel`` (built with ``prepare_observations``) and assimilated by
# ``gaussian_filter`` as a masked affine observation update at the relevant
# time steps. The ODE update and the observation update are applied
# sequentially within each step (the observation update sees the tighter,
# ODE-updated prior). The filter returns two log-likelihoods: one for the ODE
# residual (``log_likelihood``) and one for the observations
# (``log_likelihood_obs``).
#
# A = E2 (shape [1, 3]) operates on the full state X = [x, dx, ddx], so we set
# full_state=True to observe the acceleration ddx directly.
accel_obs = Measurement(
    A=prior.E2,
    z=accel_z,
    z_t=accel_ts,
    noise=accel_noise_std,
    full_state=True,  # A operates on full state X, not just x
)

# ODE-only measure (observations are supplied separately via obs_model)
measure_accel = SecondOrderODEInformation(vf, prior.E0, prior.E1, prior.E2)

# Build the observation model on the filter time grid ts = linspace(t0, t1, N+1)
obs_model = prepare_observations([accel_obs], prior.E0, ts)

# Run filter (non-jitted: prepare_observations resolves obs times eagerly).
# calibration="none" reproduces the old static ekf1_sqr_loop behavior.
result_a = gaussian_filter(
    mu_0,
    Sigma_0_sqr,
    prior,
    measure_accel,
    tspan,
    N,
    calibration="none",
    obs_model=obs_model,
)
ll_ode = result_a.log_likelihood
ll_obs = result_a.log_likelihood_obs

m_smooth_a, P_smooth_sqr_a = rts_smoother(prior, result_a)
m_smooth_a = np.array(m_smooth_a)
P_smooth_sqr_a = np.array(P_smooth_sqr_a)

# %%
# Compare: ODE-only vs ODE + acceleration measurements
P_a = np.einsum("ijk,ijl->ikl", P_smooth_sqr_a, P_smooth_sqr_a)

fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(10, 7), sharex=True)

# Position
ax1.plot(ts, m_smooth_a[:, 0], label="with accel. obs")
ax1.plot(ts, x_true, "k--", label="true")
ax1.fill_between(
    ts,
    m_smooth_a[:, 0] - 2 * np.sqrt(P_a[:, 0, 0]),
    m_smooth_a[:, 0] + 2 * np.sqrt(P_a[:, 0, 0]),
    alpha=0.3,
)
ax1.set_ylabel("x(t)"), ax1.legend()
ax1.set_title("Position estimate (ODE + acceleration measurements)")

# Acceleration (index 2 in state [x, dx, ddx])
ax2.scatter(accel_ts, accel_z, s=20, color="red", zorder=3, label="observations")
ax2.plot(ts, m_smooth_a[:, 2], label="smoothed ddx")
ax2.plot(ts, ddx_true, "k--", label="true ddx")
ax2.fill_between(
    ts,
    m_smooth_a[:, 2] - 2 * np.sqrt(P_a[:, 2, 2]),
    m_smooth_a[:, 2] + 2 * np.sqrt(P_a[:, 2, 2]),
    alpha=0.3,
)
ax2.set_xlabel("t"), ax2.set_ylabel("ddx(t)"), ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Decoupling the ODE model from the observation schedule
#
# External observations are decoupled from the ODE model: the ODE information
# (`SecondOrderODEInformation`) describes the dynamics, while the measurement
# schedule is supplied separately as an `ObsModel` built with
# `prepare_observations`. Within each filter step, `gaussian_filter` applies the
# ODE update first and then the observation update, so the observation update sees
# a tighter, ODE-informed prior.
#
# The filter reports two log-likelihoods:
#
# 1. **ODE log-likelihood** (`result.log_likelihood`) -- from the ODE residual.
# 2. **Observation log-likelihood** (`result.log_likelihood_obs`) -- from the
#    assimilated observations.
#
# The total marginal log-likelihood is their sum.

# %%
# Inspect the two log-likelihood contributions from the run above
print(f"ODE residual log-likelihood:   {float(ll_ode):.4f}")
print(f"Observation log-likelihood:    {float(ll_obs):.4f}")
print(f"Total log-likelihood:          {float(ll_ode) + float(ll_obs):.4f}")
